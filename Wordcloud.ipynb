# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
tweets=pd.read_csv('/Users/saksheeagarwal/Downloads/my_clean_tweets.csv', sep=',')
tweets.sample(10)
# Out:
#                                                  Message        Date  \
# 47650  aapl funny thing morning nasdaq future went ap...  2021-03-09
# 36379  amd aapl qqq lulu xlnx oh bears come come wher...  2021-04-07
# 42323  aapl look facebook today company apple picking...  2021-03-19
# 2681   aapl sure tired moving careful lots profit tak...  2021-06-28
# 45298  aapl last buy next week let idiots sell cant g...  2021-03-12
# 13365                       aapl investing crap amc moon  2021-06-02
# 4741   aapl screw buying scaling couple hundred puts ...  2021-06-21
# 26757                    aapl chip shortage issue hidden  2021-04-28
# 43328  aapl one actually trading right usual early ma...  2021-03-18
# 1028   smartoptions unusual activity alert delayed aa...  2021-07-02
#
#        Sentiment lang
# 47650          1   en
# 36379          1   en
# 42323          0   en
# 2681           0   en
# 45298          1   en
# 13365          1   en
# 4741           0   en
# ...

# %%
not_ticker = []

for text in tweets[tweets['Sentiment']==1]['Message']:
    for word in text.split():
        if word not in ['aapl', 'tsla']:
            not_ticker.append(word)

words = ' '.join([word for word in not_ticker])
wordcloud = WordCloud(width=800, height=400, background_color='white', max_font_size=110, max_words=100).generate(words)
plt.figure(figsize=(14, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.title('Words in positive tweets\n', fontsize=32)
plt.axis('off')
plt.show()

# %%
not_ticker = []

for text in tweets[tweets['Sentiment']==0]['Message']:
    for word in text.split():
        if word not in ['aapl', 'tsla']:
            not_ticker.append(word)

words = ' '.join([word for word in not_ticker])
wordcloud = WordCloud(width=800, height=400, background_color='white', max_font_size=110, max_words=100).generate(words)
plt.figure(figsize=(14, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.title('Words in negative tweets\n', fontsize=32)
plt.axis('off')
plt.show()
